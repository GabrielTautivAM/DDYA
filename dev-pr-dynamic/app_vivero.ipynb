# %% [markdown]
# ## Problema - Organización y búsqueda de productos en una tienda
#
# **Instrucción:** completa esta plantilla con tu diseño y desarrollo. Evita incluir soluciones generadas automáticamente.

# %%
# @title Ingrese datos
nombre_estudiante = "Gabriel Andrés Tautiva Amado" # @param {"type":"string"}
carnet = 1014659008 # @param {"type":"integer"}

# %% [markdown]
# ## 1) Descripción del problema **[1 pts]**
#
# Un vivero está analizando el crecimiento de la producción de nuevas plantas a partir de un proceso de reproducción controlada.
# Se ha observado que el número de nuevas plantas producidas en el mes n sigue el siguiente comportamiento:
# • En el mes 0 se produjeron 0 nuevas plantas.
# • En el mes 1 se produjo 1 nueva planta.
# • A partir del mes 2, el número de nuevas plantas producidas es igual a la suma de las plantas producidas durante los dos meses anteriores, debido a que las plantas que alcanzan su etapa de reproducción generan nuevos brotes siguiendo este patrón de crecimiento.
# Relación de recurrencia:
# T(n) = 0 si n = 0
# T(n) = 1 si n = 1
# T(n) = T(n-1) + T(n-2) si n ≥ 2
# Determinar con memoización cuántas nuevas plantas serán producidas en el mes n.

# %% [markdown]
# ## 2) Requerimientos **[2 pts]**
#
# Lista requerimientos **funcionales** y **no funcionales**.
#
#
# Requerimientos funcionales
#
# RQF01: Solicitar y validar el mes del cual se desea hacer el calculo y verificar si es posible
#
# RQF02: Definir casos base
#
# RQF03: Verificar si el valor no ha sido calculado anteriormente
#
# RQF04: En caso de no haber sido calculado anteriormente, hacer el respectivo calculo
#
# RQF05: Imprimir la respuesta
#
#
#
# Requerimientos no funcionales
#
# RQNF01: Baja complejidad, el programa cuenta con una baja complejidad, lo cual permite realizar calculos grandes sin costos adicionales
#
# RQFN02: Memoizacion, para que el programa sea de baja omplejidad, es necesario que almacene las respuestas guardadas, cosa que se realiza por medio de la memoizacion y se almacenan en memoria.
#
# RQNF03: Modularidad, el programa se encuentra escrito de forma modular para facilitar la correcion de eerores o modificacion futura.
#
# RQNF04: Python, El lenguaje de programacion usado para etse programa fue Python, la razon es que es un lenguaje de alto nivel bastante flexible y facil de usar y comprender

# %% [markdown]
# ## 3) Historias de usuario **[2 pts]**
# Escribe 3–5 historias de usuario con el formato visto en clase:
# Incluye criterios de aceptación.
#
# Historis de usuario:
#
# HU01: Ingresar el numero del mes. RQF01
# caso de error: un mes menor a 0
# caso de aceptacion: mes mayor o igual a 0
#
# HU02: Verificacion del mes RF01
# Caso de error: un mes menor a 0
# Caso de aceptacion: mes mayor o igual a 0
# Salida de error: Digite nuevamente
#
# HU03: Casos base y calculo: RQF03, RQF04 Y RQF05
# en este caso, no hay casos de aceptacion, pues los anteriores se encargaron de realizar la verificacion

# %% [markdown]
# ## 4) Diagramas de flujo **[5 pts]**
# Incluye el diagrama que muestre el proceso general
#
# ![diagrama de flujo dinal.drawio.png](<attachment:diagrama de flujo dinal.drawio.png>)
#
# ![Diagrama sin título.drawio (3).jpg](<attachment:Diagrama sin título.drawio (3).jpg>)
#
# ![Diagrama sin título.drawio (4).jpg](<attachment:Diagrama sin título.drawio (4).jpg>)
#
#
# El programa hace una bienvenida y una breve explicaicon del programa, depsues solicita el numero del mes y lo comprueba, en caso de no ser valido, deja al usuario en un ciclo hasta que ingrese un valor valido.
#
# El programa recibe un mes n y memo, como memo siempre sera none, se inicia el iccionario el cual funciona como el acumulador de las respuestas de las nuevas plantas a apartir del numero de meses, que en este caso es de n.
#
# Si n es igual a 0 o a 1, el programa retonara 0 o 1 respectivamente, pues estos son los casos base de la recursividad de las plantas.
#
# Si por otro lado, n es un valor distinto de 0 y de 1,en caso de ya haberlo calculado anteriormente, arroja el valor calculaod para dicho mes, en caso de que no, se procede a calcularlo y guardarlo en el diciconario para evitar realizar calculos innecesarios para futuros valores de n, que en este caso seria futuros calculos para meses posteriores.

# %% [markdown]
# ### 5) Análisis de complejidad **[15 pts]**
# Incluye:
# - Justificación
# - Función T[n]
# - Mejor y peor caso con gráfica
#
# ![image.png](attachment:image.png)
#
# Mejores casos:
#
# ![image-2.png](attachment:image-2.png)
#
# peor caso
#
# ![image-3.png](attachment:image-3.png)
#
# $T[n] = O(n) $
#
# la ecuacion corresponde a esto gracias a la confirmacion del programa para el mes y porque la memoizacion tiene un costo de $O(n)$, pues la complejidad dependera del mes que se quiera calcular

# %% [markdown]
# ## 6) Código funcional **[15 pts]**
# Incluye tu implementación completa.
#
# No pegues código incompleto; debe ser ejecutable.

# %%
def solicitar_mes():
    print("por favor escriba el numero del mes en el que desea calcular el numero de plantas")
    x = int(input())
    while x < 0:
        print("el programa no puede calcular para meses negativos")
        x = int(input())
    return x

def plantas_nuevas(n, memo=None):
    if memo is None:
        memo = {}

    if n == 0: 
        memo[n] = 0
        return 0
    elif n == 1:
        memo[n] = 1  
        return 1    
    elif n in memo:
        return memo[n]
    else:
        nueva_planta = plantas_nuevas(n - 1) + plantas_nuevas(n - 2)
        memo[n] = nueva_planta
        return memo[n]

def main():
    print("bienvenido al programa")
    print()
    print("este programa calculara el numero de plantas que habran en el mes el cual usted desee solicitar")
    n = solicitar_mes()
    x = plantas_nuevas(n)

    print("el numero de plantas que habra en el mes", n, "seran", x ,"plantas")


main()

# %% [markdown]
# ## 7) Tests aplicados **[15 pts]**

# %%
# (Opcional) Ejemplo de asserts (ajusta a tu código):
# assert funcion(0) == 0
# assert funcion(1) == 1
# assert funcion(6) == 8


def plantas_nuevas(n, memo=None):
    if memo is None:
        memo = {}

    if n == 0: 
        memo[n] = 0
        return 0
    elif n == 1:
        memo[n] = 1  
        return 1    
    elif n in memo:
        return memo[n]
    else:
        nueva_planta = plantas_nuevas(n - 1) + plantas_nuevas(n - 2)
        memo[n] = nueva_planta
        return memo[n]

    print("para el mes 0, se tiene un total de", plantas_nuevas(0))
    print("para el mes 1, se tiene un total de", plantas_nuevas(1))
    print("para el mes 6, se tiene un total de", plantas_nuevas(6))
# Out:
# Running cells with 'Python 3.11.9' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '"c:/Program Files/Python311/python.exe" -m pip install ipykernel -U --user --force-reinstall'
